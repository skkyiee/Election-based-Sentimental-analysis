# %% [markdown]
# ##  **Model 1: GloVe (Global Vectors for Word Representation)**
# We have decided to test two models and use the model with the better accuracy for our project.We choose GloVe as one of the models  as using GloVe helps:
#
# *   Deal with short, slang-filled tweets more effectively
# *   Understand word relationships and sentiment better
#
# *   Leverage pre-trained knowledge without needing millions of examples
#
# GloVe is an unsupervised learning algorithm that generates vector representations for words, also known as word embeddings.

# %%
# !pip install preprocessor
# !pip install tensorflow
# Out:
# Requirement already satisfied: preprocessor in /usr/local/lib/python3.11/dist-packages (1.1.3)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
import pandas as pd
from nltk.tokenize import word_tokenize
from string import punctuation
from nltk.corpus import stopwords
import re
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import keras
import numpy as np
from tensorflow.keras.layers import Embedding, SimpleRNN,Input
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.layers import Embedding, Flatten, Dense,Conv1D,MaxPooling1D
from sklearn import preprocessing
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import itertools
import seaborn as sns
from sklearn.metrics import confusion_matrix
from tensorflow.keras.utils import to_categorical
from collections import Counter
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
election = pd.read_csv('/content/election.csv')
election.head()
# Out:
#                     id                                         clean_text  \
# 0          1.11772E+18  RT chitraSD Jogging RahulGandhi ’ memory famil...
# 1  1118061974292533249  AAP INC want alliance stop division Anti-Modi ...
# 2  1117870131969810432  RT pankaj_shankar She priyankagandhi slams Mod...
# 3           1.1177E+18  RT airnewsalerts SC says RahulGandhi 's remark...
# 4  1117850484327366656  RT sachinsingh1010 75 year old Govindraj kille...
#
#    polarity                place
# 0         0               Madras
# 1         0                  NaN
# 2         0                  NaN
# 3         0            New Delhi
# 4         0  New Delhi Varanasi

# %% [markdown]
# We need to perform further cleaning as there more unwanted elements in the text as you can see above like the Phrase RT and so.

# %%
def tweet_to_words( raw_review ):

    letters_only = re.sub("[^a-zA-Z]", " ", raw_review)
    tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))', 'URL', letters_only) # remove URLs
    tweet = re.sub('RT', ' ', str(tweet))

    #Convert to lower case, split into individual words
    tweet = letters_only.lower().split()

    return( " ".join(tweet))

# %%
election['id'].count()
# Out:
# np.int64(10365)

# %%
num_tweets = 10365
clean_train_tweets = []


for i in range( 0, num_tweets ):
    # Call function for each one, and add the result to the list of clean reviews
    clean_train_tweets.append( tweet_to_words( election["clean_text"][i] ) )

# %%
data_inputs =  clean_train_tweets
data_labels = list(election.polarity)

# %%
tokenizer = Tokenizer(nb_words=2000)
tokenizer.fit_on_texts(data_inputs)
sequences = tokenizer.texts_to_sequences(data_inputs)

word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))

data = pad_sequences(sequences, maxlen=1000)

labels = keras.utils.to_categorical(np.asarray(data_labels))
print('Shape of data tensor:', data.shape)
print('Shape of label tensor:', labels.shape)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/legacy/preprocessing/text.py:98: UserWarning: The `nb_words` argument in `Tokenizer` has been renamed `num_words`.
#   warnings.warn(
# Found 8213 unique tokens.
# Shape of data tensor: (10365, 1000)
# Shape of label tensor: (10365, 2)

# %% [markdown]
# **SPLITTING THE DATA INTO TRAING ANG TESTING DATA IN 80:20 RATIO**

# %%
indices = np.arange(data.shape[0])
np.random.shuffle(indices)
data = data[indices]
labels = labels[indices]
nb_validation_samples = int(.20 * data.shape[0])

x_train = data[:-nb_validation_samples]
y_train = labels[:-nb_validation_samples]
x_val = data[-nb_validation_samples:]
y_val = labels[-nb_validation_samples:]

# %% [markdown]
# **USING THE PRETRAINED MODEL : GloVe TO CREATE WORD EMBEDDING MATRIX**

# %%
embeddings_index = {}
f = open( r"/content/glove.6B.100d.txt", encoding ="utf-8")
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 239099 word vectors.

# %%
embedding_matrix = np.zeros((len(word_index) + 1, 100))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector

# %%
embedding_layer = Embedding(len(word_index) + 1,
                            100,
                            weights=[embedding_matrix],
                            input_length=1000,
                            trainable=False)

# %% [markdown]
# ### **CREATING THE MODEL**
#
# (CREDIT:ABISHIEK CITDED IN REFERENCE)

# %%
def model_creation():
    input_layer = Input(shape=(1000,), dtype='int32')
    embed_layer = embedding_layer(input_layer)
    x = Dense(100, activation='relu')(embed_layer)
    x = Dense(50, activation='relu', kernel_regularizer=keras.regularizers.l2(0.002))(x)
    x = Flatten()(x)
    x = Dense(50, activation='relu', kernel_regularizer=keras.regularizers.l2(0.002))(x)
    x = Dropout(0.5)(x)
    x = Dense(50, activation='relu')(x)
    x = Dropout(0.5)(x)
    final_layer = Dense(1, activation='sigmoid')(x)

    opt = keras.optimizers.Adam(learning_rate=learning_rate, beta_1=0.9, beta_2=0.999, amsgrad=False)
    model = Model(input_layer, final_layer)
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

    return model

# %%
learning_rate = 0.0001
batch_size = 1024
epochs = 10
y_train_binary = np.argmax(y_train, axis=1)
y_val_binary = np.argmax(y_val, axis=1)

model_glove = model_creation()
model_final = model_glove.fit(x_train, y_train_binary, validation_data=(x_val, y_val_binary),epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 45s 4s/step - accuracy: 0.5308 - loss: 1.0158 - val_accuracy: 0.7062 - val_loss: 0.9745
# Epoch 2/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 78s 4s/step - accuracy: 0.6213 - loss: 0.9647 - val_accuracy: 0.7221 - val_loss: 0.9268
# Epoch 3/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.6548 - loss: 0.9192 - val_accuracy: 0.7168 - val_loss: 0.8828
# Epoch 4/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.6616 - loss: 0.8792 - val_accuracy: 0.7516 - val_loss: 0.8417
# Epoch 5/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.6779 - loss: 0.8408 - val_accuracy: 0.7651 - val_loss: 0.8048
# Epoch 6/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.7137 - loss: 0.8033 - val_accuracy: 0.7699 - val_loss: 0.7676
# Epoch 7/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.7134 - loss: 0.7723 - val_accuracy: 0.7699 - val_loss: 0.7321
# Epoch 8/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.7253 - loss: 0.7448 - val_accuracy: 0.7795 - val_loss: 0.7017
# Epoch 9/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 43s 4s/step - accuracy: 0.7561 - loss: 0.7083 - val_accuracy: 0.7998 - val_loss: 0.6692
# Epoch 10/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.7644 - loss: 0.6858 - val_accuracy: 0.7800 - val_loss: 0.6424

# %% [markdown]
# ### **Training the model further....**

# %%
model_final = model_glove.fit(x_train, y_train_binary, validation_data=(x_val, y_val_binary),epochs=100, batch_size=batch_size)
# Out:
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 37s 4s/step - accuracy: 0.7745 - loss: 0.6511 - val_accuracy: 0.8080 - val_loss: 0.6163
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 43s 4s/step - accuracy: 0.7834 - loss: 0.6335 - val_accuracy: 0.7993 - val_loss: 0.5948
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.7914 - loss: 0.6133 - val_accuracy: 0.8152 - val_loss: 0.5733
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.8026 - loss: 0.5889 - val_accuracy: 0.8201 - val_loss: 0.5557
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.8138 - loss: 0.5714 - val_accuracy: 0.8263 - val_loss: 0.5413
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.8330 - loss: 0.5545 - val_accuracy: 0.8321 - val_loss: 0.5249
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 43s 4s/step - accuracy: 0.8330 - loss: 0.5460 - val_accuracy: 0.8326 - val_loss: 0.5106
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.8307 - loss: 0.5307 - val_accuracy: 0.8408 - val_loss: 0.4991
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 43s 4s/step - accuracy: 0.8490 - loss: 0.5130 - val_accuracy: 0.8461 - val_loss: 0.4902
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 37s 4s/step - accuracy: 0.8457 - loss: 0.5120 - val_accuracy: 0.8476 - val_loss: 0.4826
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.8471 - loss: 0.4997 - val_accuracy: 0.8490 - val_loss: 0.4714
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 46s 5s/step - accuracy: 0.8594 - loss: 0.4782 - val_accuracy: 0.8505 - val_loss: 0.4634
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 78s 4s/step - accuracy: 0.8549 - loss: 0.4832 - val_accuracy: 0.8548 - val_loss: 0.4569
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - accuracy: 0.8708 - loss: 0.4641 - val_accuracy: 0.8534 - val_loss: 0.4497
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.8763 - loss: 0.4504 - val_accuracy: 0.8543 - val_loss: 0.4413
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - accuracy: 0.8688 - loss: 0.4534 - val_accuracy: 0.8558 - val_loss: 0.4341
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.8743 - loss: 0.4438 - val_accuracy: 0.8587 - val_loss: 0.4273
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 37s 4s/step - accuracy: 0.8839 - loss: 0.4280 - val_accuracy: 0.8611 - val_loss: 0.4209
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.8827 - loss: 0.4227 - val_accuracy: 0.8712 - val_loss: 0.4146
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.8832 - loss: 0.4202 - val_accuracy: 0.8712 - val_loss: 0.4107
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.8879 - loss: 0.4116 - val_accuracy: 0.8789 - val_loss: 0.4028
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 37s 4s/step - accuracy: 0.8925 - loss: 0.4019 - val_accuracy: 0.8813 - val_loss: 0.3978
# Epoch 23/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.8975 - loss: 0.3928 - val_accuracy: 0.8765 - val_loss: 0.3953
# Epoch 24/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.8964 - loss: 0.3955 - val_accuracy: 0.8813 - val_loss: 0.3894
# Epoch 25/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 37s 4s/step - accuracy: 0.8991 - loss: 0.3853 - val_accuracy: 0.8799 - val_loss: 0.3895
# Epoch 26/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.9012 - loss: 0.3821 - val_accuracy: 0.8837 - val_loss: 0.3816
# Epoch 27/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - accuracy: 0.9002 - loss: 0.3796 - val_accuracy: 0.8895 - val_loss: 0.3760
# Epoch 28/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9085 - loss: 0.3694 - val_accuracy: 0.8876 - val_loss: 0.3721
# Epoch 29/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.9082 - loss: 0.3654 - val_accuracy: 0.8939 - val_loss: 0.3672
# Epoch 30/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9133 - loss: 0.3615 - val_accuracy: 0.8953 - val_loss: 0.3628
# Epoch 31/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.9092 - loss: 0.3596 - val_accuracy: 0.8963 - val_loss: 0.3602
# Epoch 32/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.9081 - loss: 0.3566 - val_accuracy: 0.8929 - val_loss: 0.3553
# Epoch 33/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9188 - loss: 0.3430 - val_accuracy: 0.8977 - val_loss: 0.3512
# Epoch 34/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - accuracy: 0.9214 - loss: 0.3406 - val_accuracy: 0.8982 - val_loss: 0.3504
# Epoch 35/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 37s 4s/step - accuracy: 0.9198 - loss: 0.3417 - val_accuracy: 0.8997 - val_loss: 0.3465
# Epoch 36/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9167 - loss: 0.3395 - val_accuracy: 0.9103 - val_loss: 0.3421
# Epoch 37/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9248 - loss: 0.3233 - val_accuracy: 0.9055 - val_loss: 0.3394
# Epoch 38/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9212 - loss: 0.3343 - val_accuracy: 0.9079 - val_loss: 0.3354
# Epoch 39/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.9201 - loss: 0.3305 - val_accuracy: 0.9103 - val_loss: 0.3320
# Epoch 40/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.9318 - loss: 0.3160 - val_accuracy: 0.9127 - val_loss: 0.3295
# Epoch 41/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9267 - loss: 0.3201 - val_accuracy: 0.9112 - val_loss: 0.3265
# Epoch 42/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9283 - loss: 0.3119 - val_accuracy: 0.9098 - val_loss: 0.3256
# Epoch 43/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 37s 4s/step - accuracy: 0.9289 - loss: 0.3095 - val_accuracy: 0.9108 - val_loss: 0.3221
# Epoch 44/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9301 - loss: 0.3082 - val_accuracy: 0.9132 - val_loss: 0.3200
# Epoch 45/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - accuracy: 0.9335 - loss: 0.3025 - val_accuracy: 0.9151 - val_loss: 0.3173
# Epoch 46/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.9383 - loss: 0.2993 - val_accuracy: 0.9156 - val_loss: 0.3146
# Epoch 47/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.9366 - loss: 0.2957 - val_accuracy: 0.9165 - val_loss: 0.3124
# Epoch 48/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9384 - loss: 0.2946 - val_accuracy: 0.9214 - val_loss: 0.3099
# Epoch 49/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.9369 - loss: 0.2981 - val_accuracy: 0.9223 - val_loss: 0.3069
# Epoch 50/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.9413 - loss: 0.2856 - val_accuracy: 0.9209 - val_loss: 0.3044
# Epoch 51/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.9380 - loss: 0.2855 - val_accuracy: 0.9214 - val_loss: 0.3020
# Epoch 52/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.9427 - loss: 0.2838 - val_accuracy: 0.9194 - val_loss: 0.3013
# Epoch 53/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 37s 4s/step - accuracy: 0.9429 - loss: 0.2775 - val_accuracy: 0.9243 - val_loss: 0.2982
# Epoch 54/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9472 - loss: 0.2739 - val_accuracy: 0.9219 - val_loss: 0.2965
# Epoch 55/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9442 - loss: 0.2744 - val_accuracy: 0.9199 - val_loss: 0.2950
# Epoch 56/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9443 - loss: 0.2761 - val_accuracy: 0.9286 - val_loss: 0.2942
# Epoch 57/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.9479 - loss: 0.2656 - val_accuracy: 0.9238 - val_loss: 0.2916
# Epoch 58/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9481 - loss: 0.2700 - val_accuracy: 0.9247 - val_loss: 0.2889
# Epoch 59/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.9513 - loss: 0.2545 - val_accuracy: 0.9301 - val_loss: 0.2868
# Epoch 60/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9479 - loss: 0.2628 - val_accuracy: 0.9296 - val_loss: 0.2847
# Epoch 61/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9497 - loss: 0.2550 - val_accuracy: 0.9320 - val_loss: 0.2825
# Epoch 62/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - accuracy: 0.9519 - loss: 0.2570 - val_accuracy: 0.9291 - val_loss: 0.2810
# Epoch 63/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.9524 - loss: 0.2514 - val_accuracy: 0.9334 - val_loss: 0.2775
# Epoch 64/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9529 - loss: 0.2496 - val_accuracy: 0.9329 - val_loss: 0.2762
# Epoch 65/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.9564 - loss: 0.2438 - val_accuracy: 0.9354 - val_loss: 0.2757
# Epoch 66/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9556 - loss: 0.2475 - val_accuracy: 0.9276 - val_loss: 0.2773
# Epoch 67/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9544 - loss: 0.2456 - val_accuracy: 0.9368 - val_loss: 0.2753
# Epoch 68/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9558 - loss: 0.2438 - val_accuracy: 0.9373 - val_loss: 0.2701
# Epoch 69/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.9558 - loss: 0.2409 - val_accuracy: 0.9339 - val_loss: 0.2688
# Epoch 70/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.9569 - loss: 0.2335 - val_accuracy: 0.9339 - val_loss: 0.2685
# Epoch 71/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 37s 4s/step - accuracy: 0.9576 - loss: 0.2353 - val_accuracy: 0.9368 - val_loss: 0.2645
# Epoch 72/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9618 - loss: 0.2334 - val_accuracy: 0.9392 - val_loss: 0.2641
# Epoch 73/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9613 - loss: 0.2293 - val_accuracy: 0.9339 - val_loss: 0.2641
# Epoch 74/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9606 - loss: 0.2293 - val_accuracy: 0.9397 - val_loss: 0.2623
# Epoch 75/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 43s 4s/step - accuracy: 0.9590 - loss: 0.2303 - val_accuracy: 0.9363 - val_loss: 0.2593
# Epoch 76/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.9617 - loss: 0.2267 - val_accuracy: 0.9407 - val_loss: 0.2591
# Epoch 77/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 37s 4s/step - accuracy: 0.9620 - loss: 0.2273 - val_accuracy: 0.9363 - val_loss: 0.2572
# Epoch 78/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 37s 4s/step - accuracy: 0.9609 - loss: 0.2237 - val_accuracy: 0.9411 - val_loss: 0.2560
# Epoch 79/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 43s 4s/step - accuracy: 0.9614 - loss: 0.2202 - val_accuracy: 0.9411 - val_loss: 0.2538
# Epoch 80/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.9646 - loss: 0.2186 - val_accuracy: 0.9426 - val_loss: 0.2535
# Epoch 81/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9623 - loss: 0.2223 - val_accuracy: 0.9402 - val_loss: 0.2510
# Epoch 82/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9623 - loss: 0.2179 - val_accuracy: 0.9431 - val_loss: 0.2506
# Epoch 83/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9633 - loss: 0.2152 - val_accuracy: 0.9402 - val_loss: 0.2539
# Epoch 84/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.9666 - loss: 0.2110 - val_accuracy: 0.9460 - val_loss: 0.2499
# Epoch 85/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.9643 - loss: 0.2119 - val_accuracy: 0.9431 - val_loss: 0.2447
# Epoch 86/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 37s 4s/step - accuracy: 0.9655 - loss: 0.2084 - val_accuracy: 0.9431 - val_loss: 0.2456
# Epoch 87/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 37s 4s/step - accuracy: 0.9692 - loss: 0.2056 - val_accuracy: 0.9489 - val_loss: 0.2421
# Epoch 88/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.9731 - loss: 0.1970 - val_accuracy: 0.9469 - val_loss: 0.2405
# Epoch 89/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 37s 4s/step - accuracy: 0.9694 - loss: 0.2055 - val_accuracy: 0.9508 - val_loss: 0.2393
# Epoch 90/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9719 - loss: 0.1993 - val_accuracy: 0.9484 - val_loss: 0.2418
# Epoch 91/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 43s 4s/step - accuracy: 0.9682 - loss: 0.2049 - val_accuracy: 0.9489 - val_loss: 0.2384
# Epoch 92/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9710 - loss: 0.2019 - val_accuracy: 0.9493 - val_loss: 0.2351
# Epoch 93/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - accuracy: 0.9712 - loss: 0.1961 - val_accuracy: 0.9532 - val_loss: 0.2355
# Epoch 94/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 44s 5s/step - accuracy: 0.9714 - loss: 0.1950 - val_accuracy: 0.9542 - val_loss: 0.2354
# Epoch 95/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - accuracy: 0.9720 - loss: 0.1991 - val_accuracy: 0.9556 - val_loss: 0.2320
# Epoch 96/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 36s 4s/step - accuracy: 0.9732 - loss: 0.1941 - val_accuracy: 0.9547 - val_loss: 0.2309
# Epoch 97/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 43s 4s/step - accuracy: 0.9722 - loss: 0.1963 - val_accuracy: 0.9566 - val_loss: 0.2297
# Epoch 98/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9725 - loss: 0.1906 - val_accuracy: 0.9551 - val_loss: 0.2306
# Epoch 99/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.9720 - loss: 0.1949 - val_accuracy: 0.9566 - val_loss: 0.2286
# Epoch 100/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.9775 - loss: 0.1876 - val_accuracy: 0.9561 - val_loss: 0.2267

# %%
model_final1 = model_glove.fit(x_train,y_train_binary, validation_data=(x_val, y_val_binary),epochs=20, batch_size=batch_size)
# Out:
# Epoch 1/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.9753 - loss: 0.1865 - val_accuracy: 0.9551 - val_loss: 0.2264
# Epoch 2/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.9751 - loss: 0.1823 - val_accuracy: 0.9561 - val_loss: 0.2275
# Epoch 3/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9771 - loss: 0.1801 - val_accuracy: 0.9571 - val_loss: 0.2253
# Epoch 4/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.9783 - loss: 0.1823 - val_accuracy: 0.9571 - val_loss: 0.2239
# Epoch 5/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9752 - loss: 0.1831 - val_accuracy: 0.9585 - val_loss: 0.2234
# Epoch 6/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 37s 4s/step - accuracy: 0.9742 - loss: 0.1843 - val_accuracy: 0.9556 - val_loss: 0.2240
# Epoch 7/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.9761 - loss: 0.1778 - val_accuracy: 0.9595 - val_loss: 0.2207
# Epoch 8/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9751 - loss: 0.1810 - val_accuracy: 0.9590 - val_loss: 0.2204
# Epoch 9/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9767 - loss: 0.1821 - val_accuracy: 0.9580 - val_loss: 0.2202
# Epoch 10/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9797 - loss: 0.1768 - val_accuracy: 0.9595 - val_loss: 0.2205
# Epoch 11/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.9779 - loss: 0.1771 - val_accuracy: 0.9575 - val_loss: 0.2191
# Epoch 12/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9784 - loss: 0.1721 - val_accuracy: 0.9590 - val_loss: 0.2188
# Epoch 13/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9789 - loss: 0.1733 - val_accuracy: 0.9595 - val_loss: 0.2178
# Epoch 14/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9794 - loss: 0.1739 - val_accuracy: 0.9585 - val_loss: 0.2194
# Epoch 15/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9773 - loss: 0.1733 - val_accuracy: 0.9609 - val_loss: 0.2155
# Epoch 16/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9819 - loss: 0.1677 - val_accuracy: 0.9595 - val_loss: 0.2157
# Epoch 17/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - accuracy: 0.9792 - loss: 0.1690 - val_accuracy: 0.9619 - val_loss: 0.2136
# Epoch 18/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9809 - loss: 0.1681 - val_accuracy: 0.9624 - val_loss: 0.2127
# Epoch 19/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.9813 - loss: 0.1682 - val_accuracy: 0.9624 - val_loss: 0.2129
# Epoch 20/20
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9819 - loss: 0.1678 - val_accuracy: 0.9629 - val_loss: 0.2120

# %% [markdown]
# ### **SAVING THE MODEL AND THE WEIGHTS**

# %%
#create directory
import os
os.makedirs("./SavedModels", exist_ok=True)


# Save model architecture
model_json = model_glove.to_json()
with open("./SavedModels/Model_glove.json", "w") as json_file:  # use .json for architecture
    json_file.write(model_json)

# Save weights (must end with `.weights.h5`)
model_glove.save_weights("./SavedModels/Weights_glove.weights.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# ### **CALCULATE THE MODEL LOSS AND ACCURACY**

# %%
loss,acc = model_glove.evaluate(x_val,y_val_binary, verbose = 2, batch_size = batch_size)
print("Validation Loss: %.2f" % (loss))
print("Validation Accuracy: %.2f" % (acc))
# Out:
# 3/3 - 3s - 1s/step - accuracy: 0.9629 - loss: 0.2120
# Validation Loss: 0.21
# Validation Accuracy: 0.96

# %% [markdown]
# ### **PLOTTING THE MODEL PERFORMANCE METRICS**

# %%
def plot_modelacc(fit_model):
    with plt.style.context('ggplot'):
        plt.plot(fit_model.history['accuracy'])
        plt.plot(fit_model.history['val_accuracy'])
        plt.ylim(0, 1)
        plt.title("MODEL ACCURACY")
        plt.xlabel("# of EPOCHS")
        plt.ylabel("ACCURACY")
        plt.legend(['train', 'test'], loc='upper left')
    return plt.show()

# %%
def plot_model_loss(fit_model):
    with plt.style.context('ggplot'):
            plt.plot(fit_model.history['loss'])
            plt.plot(fit_model.history['val_loss'])
            plt.title("MODEL LOSS")
            plt.xlabel("# of EPOCHS")
            plt.ylabel("LOSS")
            plt.legend(['train', 'test'], loc='upper left')
    return plt.show()

# %%
plot_modelacc(model_final)

# %%
plot_model_loss(model_final)

# %% [markdown]
# ### **CONFUSION MATRIX**
#
# A CONFUSION MATRIX CAN BE USED TO DEPICT THE VALUES THAT THE MODEL HAS PREDICTED AND COMPARE WITH IT THE ACTUAL RESULTS TO REACH A CONCLUSION ABOUT THE ACCURACY OF THE MODEL.

# %%
y_pred = model_glove.predict(x_val)

# Apply 0.5 threshold
y_pred = (y_pred > 0.5).astype(int)

# Convert one-hot encoded y_val to labels
y_val_labels = y_val.argmax(axis=1)

# Flatten y_pred to 1D
y_pred_labels = y_pred.flatten()

# Compute confusion matrix
cm = confusion_matrix(y_val_labels, y_pred_labels)

# Plot
LABELS = ['negative', 'positive']
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=LABELS, yticklabels=LABELS)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step

# %% [markdown]
# True Positives: 853 (Predicted True and True in reality)<br>
# True Negative: 1143(Predicted False and False in realtity)<br>
# False Positive: 23 (Predicted Positve but Negative in reality)<br>
# False Negative: 54 (Predicted Negative but Positive in reality)
